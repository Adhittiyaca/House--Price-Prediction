# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhittiyaca/House--Price-Prediction/blob/main/Aashi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #House Price Prediction
# Author: Aashi
# Work Started and maintained by me

# %%
import pandas as pd
import numpy as np

print ("House Price Prediction project be Aashi")
# Out:
# House Price Prediction project be Aashi
